# %% [markdown]
# 1. Find missing values

# %%
# A. Read in the file into a Pandas DataFrame
# B. Do some initial explorations
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('student-mat-missing-data.csv')
df.head()
# Out:
#    Unnamed: 0 school sex   age address  ... health absences  G1  G2  G3
# 0           0     GP   F  18.0       U  ...    3.0      6.0   5   6   6
# 1           1     GP   F  17.0       U  ...    3.0      4.0   5   5   6
# 2           2     GP   F  15.0       U  ...    3.0     10.0   7   8  10
# 3           3     GP   F  15.0       U  ...    5.0      2.0  15  14  15
# 4           4     GP   F  16.0       U  ...    5.0      4.0   6  10  10
#
# [5 rows x 34 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu  ...          G1          G2          G3
# count  395.000000  381.000000  395.000000  ...  395.000000  395.000000  395.000000
# mean   197.000000   16.700787    2.749367  ...   10.908861   10.713924   10.415190
# std    114.170924    1.275157    1.094735  ...    3.319195    3.761505    4.581443
# min      0.000000   15.000000    0.000000  ...    3.000000    0.000000    0.000000
# 25%     98.500000   16.000000    2.000000  ...    8.000000    9.000000    8.000000
# 50%    197.000000   17.000000    3.000000  ...   11.000000   11.000000   11.000000
# 75%    295.500000   18.000000    4.000000  ...   13.000000   13.000000   14.000000
# max    394.000000   22.000000    4.000000  ...   19.000000   19.000000   20.000000
#
# [8 rows x 17 columns]

# %%
df.value_counts()
# Out:
# Unnamed: 0  school  sex  age   address  famsize  Pstatus  Medu  Fedu  Mjob      Fjob      reason      guardian  traveltime  studytime  failures  schoolsup  famsup  paid  activities  nursery  higher  internet  romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0           GP      F    18.0  U        GT3      A        4     4     at_home   teacher   course      mother    2           2          0         yes        no      no    no          yes      yes     no        no        4.0     3.0       4.0    1     1     3.0     6.0       5   6   6     1
# 258         GP      M    18.0  U        GT3      T        2     1     other     other     home        mother    1           2          0         no         no      no    yes         yes      yes     yes       no        5.0     2.0       4.0    1     2     4.0     8.0       15  14  14    1
# ...

# %%
# C + D. Function to plot a barplot with the columns that have missing values
from data_utils import plot_bar

plot_bar(df)
# Out:
# <Axes: >

# %%
# E. All rows where the 'freetime' is Nan

print(f'These row indices: {df.loc[df['freetime'].isnull()].index.tolist()}')
# Out:
# These row indices: [87, 99, 130, 149, 151, 160, 191, 257, 276, 293, 308, 330, 343, 359, 372, 385]

# %%
# F. All rows where the 'freetime' or 'age' is Nan
print(f'These row indices: {df.loc[(df['age'].isnull()) | (df['freetime'].isnull())].index.tolist()}')
# Out:
# These row indices: [20, 71, 87, 99, 102, 106, 121, 130, 149, 151, 160, 188, 191, 214, 257, 270, 276, 293, 308, 330, 343, 348, 359, 372, 385]

# %%
# G. The proportion that these rows constitute of the whole dataset
